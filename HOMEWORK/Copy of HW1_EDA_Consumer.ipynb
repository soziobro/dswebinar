# %% [markdown]
# # ICPE 638 HW1
# ## Exploratory Data Analysis for Consumer Data
#
# Please follow the examples demonstrated in the class to carry out exploratory data analysis (EDA) for the consumer dataset.
#
# In your submssion:
#
# In addition to showing the output of the EDA, you will need to include the following:
#
# 1. two questions about the consumer data.
#
#   *any reasonable questions about the consumer data are ok. E.g., will high income consumers buy more? Is the spening score influnced more by the age or annual income?)*
#
# 2. answers to the questions through the EDA and arguments to support them based on your findings.

# %% [markdown]
# # Homework 1 Questions
#
# ## How are age, gender, and spending score related?
#
# ### Despite the noise and smaller sample size, we can see a slight correlation between age and spending score. This trend shows that younger people tend to have higher spending scores. Our distributions show very similar spending scores for both men and women, with women having a bigger peak around a spending score of 45.
#
# ## How does income affect spending score?
#
# ### Income and spending score have a very low corrleation, but the scatterplot shows that most people in the 40-70k$ income bracket have spending scores around 50, while low and income earners are within low and high spending score ranges.

# %%
import pandas as pd
import seaborn as sns
import numpy as np
sns.set()
df = pd.read_csv("https://raw.githubusercontent.com/jtao/AdvancedML/main/data/Mall_Customers.csv")

# %%
df
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
df.head(5)
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Gender                  200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB

# %%
df.describe().T
# Out:
#                         count    mean        std   min    25%    50%     75%  \
# CustomerID              200.0  100.50  57.879185   1.0  50.75  100.5  150.25
# Age                     200.0   38.85  13.969007  18.0  28.75   36.0   49.00
# Annual Income (k$)      200.0   60.56  26.264721  15.0  41.50   61.5   78.00
# Spending Score (1-100)  200.0   50.20  25.823522   1.0  34.75   50.0   73.00
#
#                           max
# CustomerID              200.0
# Age                      70.0
# Annual Income (k$)      137.0
# Spending Score (1-100)   99.0

# %%
df.hist(figsize=(10,10), bins=10);

# %%
df.corr().style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# <style  type="text/css" >
# #T_930f7_row0_col0,#T_930f7_row1_col1,#T_930f7_row2_col2,#T_930f7_row3_col3{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_930f7_row0_col1{
#             background-color:  #84a7fc;
#             color:  #000000;
#         }#T_930f7_row0_col2,#T_930f7_row2_col0{
#             background-color:  #bb1b2c;
#             color:  #f1f1f1;
#         }#T_930f7_row0_col3,#T_930f7_row2_col3{
#             background-color:  #8fb1fe;
#             color:  #000000;
#         }#T_930f7_row1_col0,#T_930f7_row1_col2,#T_930f7_row1_col3,#T_930f7_row3_col1{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_930f7_row2_col1{
#             background-color:  #88abfd;
#             color:  #000000;
#         }#T_930f7_row3_col0{
#             background-color:  #465ecf;
#             color:  #f1f1f1;
#         }#T_930f7_row3_col2{
#             background-color:  #4055c8;
# ...

# %%
sns.pairplot(data=df, kind="scatter", vars=[ "Age", "Annual Income (k$)","Spending Score (1-100)"], hue='Gender')

# %%
sns.violinplot(data=df[[ "Age", "Annual Income (k$)","Spending Score (1-100)"



]])
# Out:
# <AxesSubplot:>
