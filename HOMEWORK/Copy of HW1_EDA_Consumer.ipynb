# %% [markdown]
# # ICPE 638 HW1
# ## Exploratory Data Analysis for Consumer Data
#
# Please follow the examples demonstrated in the class to carry out exploratory data analysis (EDA) for the consumer dataset.
#
# In your submssion:
#
# In addition to showing the output of the EDA, you will need to include the following:
#
# 1. two questions about the consumer data.
#
#   *any reasonable questions about the consumer data are ok. E.g., will high income consumers buy more? Is the spening score influnced more by the age or annual income?)*
#
# 2. answers to the questions through the EDA and arguments to support them based on your findings.

# %%
import pandas as pd
import seaborn as sns
sns.set()
df = pd.read_csv("https://raw.githubusercontent.com/jtao/AdvancedML/main/data/Mall_Customers.csv")

# %%
df
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
df.head(5)
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Gender                  200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB

# %%
df.describe().T
# Out:
#                         count    mean        std  ...    50%     75%    max
# CustomerID              200.0  100.50  57.879185  ...  100.5  150.25  200.0
# Age                     200.0   38.85  13.969007  ...   36.0   49.00   70.0
# Annual Income (k$)      200.0   60.56  26.264721  ...   61.5   78.00  137.0
# Spending Score (1-100)  200.0   50.20  25.823522  ...   50.0   73.00   99.0
#
# [4 rows x 8 columns]

# %%
df.hist(figsize=(10,10), bins=10);

# %%
df.corr().style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# <style  type="text/css" >
# #T_1207d3e4_18e1_11ec_ae5e_0242ac1c0002row0_col0,#T_1207d3e4_18e1_11ec_ae5e_0242ac1c0002row1_col1,#T_1207d3e4_18e1_11ec_ae5e_0242ac1c0002row2_col2,#T_1207d3e4_18e1_11ec_ae5e_0242ac1c0002row3_col3{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_1207d3e4_18e1_11ec_ae5e_0242ac1c0002row0_col1{
#             background-color:  #84a7fc;
#             color:  #000000;
#         }#T_1207d3e4_18e1_11ec_ae5e_0242ac1c0002row0_col2,#T_1207d3e4_18e1_11ec_ae5e_0242ac1c0002row2_col0{
#             background-color:  #bb1b2c;
#             color:  #f1f1f1;
#         }#T_1207d3e4_18e1_11ec_ae5e_0242ac1c0002row0_col3,#T_1207d3e4_18e1_11ec_ae5e_0242ac1c0002row2_col3{
#             background-color:  #8fb1fe;
#             color:  #000000;
#         }#T_1207d3e4_18e1_11ec_ae5e_0242ac1c0002row1_col0,#T_1207d3e4_18e1_11ec_ae5e_0242ac1c0002row1_col2,#T_1207d3e4_18e1_11ec_ae5e_0242ac1c0002row1_col3,#T_1207d3e4_18e1_11ec_ae5e_0242ac1c0002row3_col1{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_1207d3e4_18e1_11ec_ae5e_0242ac1c0002row2_col1{
#             background-color:  #88abfd;
#             color:  #000000;
#         }#T_1207d3e4_18e1_11ec_ae5e_0242ac1c0002row3_col0{
#             background-color:  #465ecf;
#             color:  #f1f1f1;
#         }#T_1207d3e4_18e1_11ec_ae5e_0242ac1c0002row3_col2{
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }</style><table id="T_1207d3e4_18e1_11ec_ae5e_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >CustomerID</th>        <th class="col_heading level0 col1" >Age</th>        <th class="col_heading level0 col2" >Annual Income (k$)</th>        <th class="col_heading level0 col3" >Spending Score (1-100)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1207d3e4_18e1_11ec_ae5e_0242ac1c0002level0_row0" class="row_heading level0 row0" >CustomerID</th>
#                         <td id="T_1207d3e4_18e1_11ec_ae5e_0242ac1c0002row0_col0" class="data row0 col0" >1.00</td>
#                         <td id="T_1207d3e4_18e1_11ec_ae5e_0242ac1c0002row0_col1" class="data row0 col1" >-0.03</td>
#                         <td id="T_1207d3e4_18e1_11ec_ae5e_0242ac1c0002row0_col2" class="data row0 col2" >0.98</td>
#                         <td id="T_1207d3e4_18e1_11ec_ae5e_0242ac1c0002row0_col3" class="data row0 col3" >0.01</td>
#             </tr>
#             <tr>
#                         <th id="T_1207d3e4_18e1_11ec_ae5e_0242ac1c0002level0_row1" class="row_heading level0 row1" >Age</th>
#                         <td id="T_1207d3e4_18e1_11ec_ae5e_0242ac1c0002row1_col0" class="data row1 col0" >-0.03</td>
#                         <td id="T_1207d3e4_18e1_11ec_ae5e_0242ac1c0002row1_col1" class="data row1 col1" >1.00</td>
#                         <td id="T_1207d3e4_18e1_11ec_ae5e_0242ac1c0002row1_col2" class="data row1 col2" >-0.01</td>
#                         <td id="T_1207d3e4_18e1_11ec_ae5e_0242ac1c0002row1_col3" class="data row1 col3" >-0.33</td>
#             </tr>
#             <tr>
#                         <th id="T_1207d3e4_18e1_11ec_ae5e_0242ac1c0002level0_row2" class="row_heading level0 row2" >Annual Income (k$)</th>
#                         <td id="T_1207d3e4_18e1_11ec_ae5e_0242ac1c0002row2_col0" class="data row2 col0" >0.98</td>
#                         <td id="T_1207d3e4_18e1_11ec_ae5e_0242ac1c0002row2_col1" class="data row2 col1" >-0.01</td>
#                         <td id="T_1207d3e4_18e1_11ec_ae5e_0242ac1c0002row2_col2" class="data row2 col2" >1.00</td>
#                         <td id="T_1207d3e4_18e1_11ec_ae5e_0242ac1c0002row2_col3" class="data row2 col3" >0.01</td>
#             </tr>
#             <tr>
#                         <th id="T_1207d3e4_18e1_11ec_ae5e_0242ac1c0002level0_row3" class="row_heading level0 row3" >Spending Score (1-100)</th>
#                         <td id="T_1207d3e4_18e1_11ec_ae5e_0242ac1c0002row3_col0" class="data row3 col0" >0.01</td>
#                         <td id="T_1207d3e4_18e1_11ec_ae5e_0242ac1c0002row3_col1" class="data row3 col1" >-0.33</td>
#                         <td id="T_1207d3e4_18e1_11ec_ae5e_0242ac1c0002row3_col2" class="data row3 col2" >0.01</td>
#                         <td id="T_1207d3e4_18e1_11ec_ae5e_0242ac1c0002row3_col3" class="data row3 col3" >1.00</td>
#             </tr>
#     </tbody></table>

# %%
sns.pairplot(data=df, kind="scatter", vars=["CustomerID", "Age", "Annual Income (k$)","Spending Score (1-100)"])

# %%
sns.violinplot(data=df[["CustomerID", "Age", "Annual Income (k$)","Spending Score (1-100)"



]])
